# %% [markdown]
# # import libraries

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # read dataset

# %%
# Load the iris dataset
iris = load_iris()

data = iris.data
target = iris.target

print(f"data.shape: {data.shape}")
print(f"target.shape: {target.shape}")

X_train, X_test, y_train, y_test = train_test_split(
    data, target, test_size=0.33, random_state=42)

print(f"X_train.shape: {X_train.shape}")
print(f"X_test.shape: {X_test.shape}")
print(f"y_train.shape: {y_train.shape}")
print(f"y_test.shape: {y_test.shape}")
# Out:
# data.shape: (150, 4)
# target.shape: (150,)
# X_train.shape: (100, 4)
# X_test.shape: (50, 4)
# y_train.shape: (100,)
# y_test.shape: (50,)

# %% [markdown]
# # define rule based functions

# %%
def predict(petal_length):
    if petal_length < 2:
        return 0
    elif petal_length >= 2 and petal_length < 5:
        return 1
    else:
        return 2

# %%
for item in X_test:
    print(item[2])
    break
# Out:
# 4.7

# %%
preds = [predict(item[2]) for item in X_test]
preds
# Out:
# [1,
#  0,
#  2,
#  1,
#  1,
#  0,
#  1,
#  2,
#  1,
#  1,
#  2,
#  0,
#  0,
#  0,
#  0,
#  1,
#  2,
#  1,
#  1,
#  2,
#  0,
#  1,
#  0,
#  2,
#  2,
#  2,
#  2,
#  2,
#  0,
#  0,
#  0,
#  0,
#  1,
#  0,
#  0,
#  2,
#  1,
#  0,
#  0,
#  0,
#  2,
#  1,
#  1,
#  0,
#  0,
#  1,
#  2,
#  2,
#  1,
#  2]

# %%
acc = []

for i in range(len(preds)):
    acc.append(preds[i] == y_test[i])

acc
# Out:
# [np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.False_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_,
#  np.True_]

# %%
np.sum(acc) / len(acc)
# Out:
# np.float64(0.98)

# %%
predict(3.8)
# Out:
# 1

# %%
# works same as knn
